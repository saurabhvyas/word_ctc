# %%
#  word level CTC  tensorflow version 1.3




# to do :   
#  , testing on realdataset , get rid of fixed batch size , instead use variable batch size  


# perform following tests :

# 1. variable batch sizes test
# 2. GPU test





# please change the following according to your system
# hyperparameters in this notebook
# words in words/words.txt file , one per line , last line has space word
# change paths in this notebook to that corresponding to your system
# please note number of audio examples in dataset must be even 

# peace.

# %%
import tensorflow as tf
from __future__ import print_function
from tensorflow.contrib import rnn
import numpy as np
import scipy.io.wavfile as wav
from python_speech_features import mfcc
from tensorflow.contrib.data import Dataset, Iterator
import time
# Out:
# /home/saurabh/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def audio_to_mfcc(fileurl):
    rate, sig = wav.read(fileurl)
    mfcc_feat = mfcc(sig,rate)
#d_mfcc_feat = delta(mfcc_feat, 2)
#fbank_feat = logfbank(sig,rate)

    return mfcc_feat

# %%
inputs = audio_to_mfcc('/home/saurabh/Documents/tf_orange/tf_orange/data/test.wav')

# %%
inputs.shape
# Out:
# (299, 13)

# %%
def decode_csv(line):
       parsed_line = tf.decode_csv(line, [[""],[""]])
       
    
       
       

       return parsed_line[0] , parsed_line[1]

# %%
# we also need a fixed vocabulary 
import re

word_dictionary = {}

with open("/home/saurabh/feeny_dataset/data/words.txt") as file:
    for i , line in enumerate(file):
        
        line = line.replace("\n", "")
        word_dictionary[line] = i

# %%
print(len(word_dictionary))
# Out:
# 52

# %%
def word_to_index(sentence):
   
    words = sentence.split(' ')
    index_list=[]
    for word in words:
       
        if word in word_dictionary:
           # print(word)
            index_list.insert(len(index_list) , word_dictionary[word])
            index_list.insert(len(index_list) , word_dictionary[' '])
    index_list.pop()        
    return index_list

# %%
word_to_index('this is a test')
# Out:
# [38]

# %%
# define a function, that pads audio so that audio frames = max frames

def pad(input):
   # print(input.shape[0])
     if input.shape[0] < timesteps:
        
        diff = timesteps - input.shape[0]
        
        # pad and return input
        return np.pad(input,((0,diff),(0,0)), mode="constant")
    
     elif input.shape[0] > timesteps:
        
        return input[:timesteps,:]

# %%
def _read_py_function(audio, label):
    audio = audio_to_mfcc(audio)
    
    if audio.shape[0] < timesteps:
        original_length=audio.shape[0]
       # print(original_length)
    
    elif audio.shape[0] >= timesteps:
        original_length=timesteps
        
    
    audio=pad(audio)
   
    return audio ,label, original_length

# %%
dataset = tf.contrib.data.TextLineDataset("/home/saurabh/Documents/tf_orange/tf_orange/feeny.csv")
dataset=dataset.map(decode_csv)



dataset = dataset.map(
    lambda audio, label: tuple(tf.py_func(
        _read_py_function, [audio, label], [tf.double, label.dtype, tf.int64])))




dataset=dataset.batch(2)

# %%
iterator = dataset.make_initializable_iterator()

item = iterator.get_next()

# %%
# this function is required for CTC Loss
# for it's input , first convert transcrition / ground truth to number representation 

def sparse_tuple_from(sequences, dtype=np.int32):
    """Create a sparse representention of x.
    Args:
        sequences: a list of lists of type dtype where each element is a sequence
    Returns:
        A tuple with (indices, values, shape)
    """
    indices = []
    values = []

    for n, seq in enumerate(sequences):
        indices.extend(zip([n]*len(seq), range(len(seq))))
        values.extend(seq)

    indices = np.asarray(indices, dtype=np.int64)
    values = np.asarray(values, dtype=dtype)
    shape = np.asarray([len(sequences), np.asarray(indices).max(0)[1]+1], dtype=np.int64)

    return indices, values, shape

# %%
# Training Parameters
learning_rate = 0.001
training_steps = 100
#batch_size = 2
display_step = 200
num_features = 13
logs_path = '/home/saurabh/Documents/tf_orange/tf_orange/feeny/logs'
model_path = '/home/saurabh/Documents/tf_orange/tf_orange/models/feeny/model.ckpt'

# Network Parameters

timesteps = 300 # timesteps
num_hidden = 128 # hidden layer num of features
num_classes = len(word_dictionary) + 1 # words.txt , all words plus space word  ( 10001) + CTC symbol (1)

# %%
#prediction = tf.nn.softmax(logits)
inputs = tf.placeholder(tf.float32, [None, None, num_features])
targets = tf.sparse_placeholder(tf.int32)
seq_len = tf.placeholder(tf.int32, [None])
batch_size = 2

#batch_size = tf.placeholder ( tf.int32 )

# %%
# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([ 2 * num_hidden, num_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# %%
def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, timesteps, n_input)
    # Required shape: 'timesteps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, timesteps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell_fw = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0)
    
    lstm_cell_bw = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0)

    
    # Get lstm cell output
    outputs, _, _ = rnn.static_bidirectional_rnn(lstm_cell_fw, lstm_cell_bw, x,
    dtype=tf.float32)
    
    #convert output shape (timesteps * batch * classes ) to (batch*timesteps*classes)
    outputs=tf.transpose( outputs , [1, 0, 2])
    
    outputs=tf.reshape(outputs, [-1,2*num_hidden])
    
  
    res =  tf.matmul(outputs, weights['out']) + biases['out']
    
    res = tf.reshape(res, [batch_size,timesteps,num_classes])
    
    return res
   # return tf.nn.softmax(tf.matmul(outputs, weights['out']) + biases['out'])

# %%
logits = RNN(inputs, weights, biases)

loss =  tf.nn.ctc_loss ( targets, logits , seq_len , time_major = False)
cost = tf.reduce_mean(loss)
optimizer = tf.train.MomentumOptimizer(learning_rate,
                                           0.9).minimize(cost)


# Option 2: tf.contrib.ctc.ctc_beam_search_decoder
    # (it's slower but you'll get better results)
decoder_input = tf.transpose(logits, [1, 0, 2])

decoded, log_prob = tf.nn.ctc_greedy_decoder(decoder_input, seq_len)

# %%
# Create a summary to monitor cost tensor
tf.summary.scalar("loss", cost)

# Merge all summaries into a single op
merged_summary_op = tf.summary.merge_all()

# %%
# 'Saver' op to save and restore all the variables
saver = tf.train.Saver()

# %%
init = tf.global_variables_initializer()

# %%
# need this for decoding word give its index key value 

def keys_of_value(dct, value):
    for k in dct:
        if isinstance(dct[k], list):
            if value in dct[k]:
                return k
        else:
            if value == dct[k]:
                return k

# %%
# testing above function 

print(keys_of_value(word_dictionary, 2419))
# Out:
# None

# %%
# Start training
with tf.Session() as sess:
    sess.run(init)
    
    # op to write logs to Tensorboard
    summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())

    # Training cycle
    for epoch in range(training_steps):
     #   avg_cost = 0.
        
        
        sess.run(iterator.initializer)
        train_cost=0
        
        while True:
            try:
                Next_element=sess.run(item)
             
            
                 
                print(Next_element[1])   
                
                batch_list = []
                
 
                for index,j in enumerate(Next_element[1]):
                    batch_list.insert(index, word_to_index(j.decode("utf-8")))
                    
                
                batch_targets = sparse_tuple_from(batch_list)
                
                print(Next_element[2])
                
                feed = {inputs: Next_element[0],
                        targets: batch_targets,
                        seq_len: Next_element[2],
                         }
	    

                batch_cost, _ , summary = sess.run([cost, optimizer , merged_summary_op ], feed)
               # print(batch_cost)
                
                train_cost += batch_cost*batch_size
                
                
                # Write logs at every iteration
                summary_writer.add_summary(summary, epoch )
                
                 # Decoding
                d = sess.run(decoded[0], feed_dict=feed)
   
                dense_decoded = tf.sparse_tensor_to_dense(d, default_value=-1).eval(session=sess)
    
                for i, seq in enumerate(dense_decoded):

                    seq = [s for s in seq if s != -1]
       
                    str_decoded = ''.join([keys_of_value(word_dictionary, x) for x in seq ])
                    print(str_decoded)
            
              
            except tf.errors.OutOfRangeError:
              print(train_cost)
              
              
              break
                
        # Save model weights to disk
    save_path = saver.save(sess, model_path)
    print("Model saved in file: %s" % save_path)
# Out:
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# turnedturnedturnedturnedturnedturnedturnedturnedturnedturnedturnedturnedturnedsometurnedturnedturnedturnedturnedturned
# turnedturnedturnedturnedturnedturnedturnedturned
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
#
#
# 9511.499450683594
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#
#
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
#
#
# 3598.6865234375
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#
# somesomesomesome
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
# somesomesomesomesomesomesomesomesome somesomesome
# somesomesomesome somesome some some somesome
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
#
#     some     some some
# 2379.2482299804688
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#
#
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
#
#
# 2105.7714233398438
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#
#
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
#
#
# 1713.0569458007812
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   the
#    circus
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# the
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#  the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# the the the circus the circus
#  to  theto  the the
# 1352.0909729003906
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  the the
#  the the  the circus
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# the thethe  thethe the circus the to
# the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
# thethethethe
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# the  circus circus
# the   to circus   to  thetothe the the circus has
# 1304.8317260742188
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   tothe
#  kindlyto to kindly  circus
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#          circus
#  to
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
#
#            circus
# 1082.6024475097656
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   to
# tohas to  circus
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#          circus
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
#   possible
#         invented circus
# 973.3058319091797
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# driving  drivingto
# to tohas invented
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#     invented    kindly circus
# driving to
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#     to driving
#   driving     invented
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# possible  possible
#  learning driving       driving  invented invented invented circus
# 851.365234375
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# driving show so learningto
# possibletohas invented kindly has  invented
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#     inventedlearning  invented  circus
# driving to
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#  learning learning
#    learning   invented invented
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# possible  possiblepossible
#        invented circus
# 781.0179901123047
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# driving show learning
# possibletohas has going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#     invented    circus
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
#
#        has
# 679.4706878662109
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  show
#  to  has going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
#  show
#        has
# 635.6649475097656
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  show so
#  thatto  has going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are has
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#  the
#   to
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# so show the    Gutenberg
# Gutenberg       has
# 598.8864135742188
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  show so
# thatthat to junket available going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are
#  the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#  the  printing
#   to
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# so show the    Gutenberg
# Gutenberg        has
# 554.8012466430664
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  show so
# that junket available going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access     Gutenberg
# Gutenberg        has
# 514.1018753051758
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as so
# that junket going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#
#   to
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  man    Gutenberg
# Gutenberg       has
# 495.4022445678711
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as so   has
# that  junket driving going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are
#  thatto
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the time
#   to
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  man    Gutenberg
# information   used   has
# 464.79356384277344
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as so   has
# that  junket driving going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    time
#   to
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# so  man    Gutenberg
# information   used   man
# 437.8315963745117
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as so
# that  junket driving going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    time
#   to
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# there's  man there's   Gutenberg
# information   used   man
# 413.6763381958008
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as so   invented
# that  junket available going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the time
#   to
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# there's  man there's   Gutenberg
# information   used   man
# 392.78331756591797
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as so   invented junket
# that  junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the time
#   to the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# there's  there's
# information   used   man
# 373.53277587890625
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as   invented junket
# that junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are  are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the
#   to the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# there's  be
# information      available
# 357.42552185058594
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as  the invented
#   junket there's  going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are  are
# access
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the
#    the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  be
# information      available
# 341.8770446777344
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as  the invented press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are   are junket
# access
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the
#    the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  be
# information      available
# 328.6904296875
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as  the invented press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are  are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the time
#    the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# so  be
# information   used   available
# 314.44243240356445
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as   invented press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are  are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the time
#    the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# so
# information you used   available
# 302.4487609863281
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as    press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are  are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the time
#    the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access
# information you used   available
# 290.801025390625
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as    press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  might  are  are
# access
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the time
#    the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access
# information you used   available
# 280.50549697875977
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  might  are  are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the time
#    the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access show
# information you used   available
# 270.4832000732422
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  might  are  are
#
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the
#    the
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access     Gutenberg
# information you used   available
# 261.28577041625977
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  might  are  are
# masses in
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the
#    the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access   so  Gutenberg
# information you used   available
# 251.97661590576172
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#    are  are
# masses in
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the time
#    the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access show  so  Gutenberg
# information you used   available
# 243.10595703125
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  a  are had are
# masses in
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the time
#    the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access show  so  Gutenberg
# information you used   available
# 235.7951889038086
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as    press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  a  are had are
# masses in
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the time
#    the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access show might so  Gutenberg
# information you used   available
# 229.08981704711914
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as    press
#   junket there's going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  a  are be are
# masses in
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the time
#   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access show might so
# information you used   available
# 222.68450927734375
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  a  you be are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the time
#     the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access show might so
# information you used   available
# 215.99702072143555
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  a  you be are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the time
#     the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might so
# information you used   available
# 210.51841354370117
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  a  you be are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the time
#    the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access show might so
# information you used   available
# 204.5974884033203
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
#  a  you be are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the time
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access show might so
# information you used   available
# 199.35450744628906
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as    press
#   junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a  you be are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the time
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access show might I
# information you used   available
# 194.28759002685547
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a  you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#     the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information you used   available
# 188.83842849731445
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as    press
#   junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a  you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information you used   available
# 183.68672561645508
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as    press
#   junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a  you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information you used   available
# 178.8623809814453
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
#   junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a  you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information  used   available
# 174.06763076782227
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   for
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a  you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information  used   available
# 169.24419784545898
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   that
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a  you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information  used   available
# 164.9361114501953
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   that
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a  you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information  used   available
# 161.34547424316406
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#  as possible the   press
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information  used   available
# 156.82964706420898
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information  used   available
# 153.10773086547852
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information  used   available
# 149.5666332244873
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information  used   available
# 145.49446487426758
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# access  might I
# information  used   available
# 141.56447982788086
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I might Gutenberg
# information  used   available
# 137.80725479125977
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I might your
# information  used   available
# 134.0989055633545
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I might your
# information  used   available
# 130.60712242126465
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you  are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I might your
# information  used   available
# 127.06865119934082
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#    the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I might your
# information  used   available
# 123.49665069580078
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I  your
# information  used   available
# 120.38235282897949
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I  your
# information  used   available
# 117.34138679504395
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I  your
# information  used   available
# 114.68218421936035
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I  your
# information  used   available
# 112.0452651977539
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I  your
# information  used   available
# 109.47594451904297
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I  your
# information  used   available
# 106.94398880004883
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I  your
# information  used   available
# 104.48297882080078
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   press
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I  your
# information  used   available
# 102.00253105163574
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing press
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I might your
# information  used   available
# 99.54995346069336
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing press
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I might your
# information  used to  available
# 97.36458778381348
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing press
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I might your
# information  used to  available
# 95.29402160644531
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing press
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I might your
# information  used to  available
# 93.270751953125
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
#   as possible the   that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   the printing press
#    to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I might your
# information  used to  available
# 91.45406723022461
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the  has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your  might I interrupt your
# information  used to  available
# 89.86279487609863
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your gentlemen might I interrupt your
# information  used to  available
# 88.1751823425293
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for first
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your gentlemen might I interrupt your
# information  used to  available
# 86.5590877532959
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for first  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your gentlemen might I interrupt your
# information  used to  available
# 86.03547477722168
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for first  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# your gentlemen might I interrupt your
# information  used to  available
# 83.70966529846191
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 82.55547523498535
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 81.16867256164551
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 79.80975723266602
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 78.49347877502441
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 77.25694274902344
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 76.08434677124023
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 74.97378063201904
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has that
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 73.77130317687988
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 72.54890823364258
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 71.33631324768066
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  in history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 70.1711654663086
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  in history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 69.11118602752686
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  in history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 68.00711441040039
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst time in history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 66.9750804901123
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  in history
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 65.67014217376709
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  in history the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information  used to  available
# 64.50540733337402
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  in history the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information that used to  available
# 63.58018493652344
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst  in history the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information that used to  available
# 62.48068046569824
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst time in history the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information that used to  available
# 61.54386615753174
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a and you three are driving
# masses for thefirst time in history the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information that used to  available
# 60.576361656188965
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a circus and you three are driving
# masses for thefirst  in history the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#   invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information that used to  available
# 59.57668590545654
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a circus and you three are driving
# masses for thefirst  in history the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#  Gutenberg invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information that used to  available
# 58.66312026977539
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a circus and you three are driving
# masses for thefirst time in history the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#  Gutenberg invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information that used to  available
# 57.73922538757324
# [b'kindly as possible the show has turned'
#  b"press junket there's some learning going"]
# [300 229]
# kindly as possible the show has
# press junket there's some learning going
# [b'into a circus and you three are driving'
#  b'masses for the first time in history the']
# [300 300]
# into a circus and you three are driving
# masses for thefirst time in history the
# [b'so Gutenberg invented the printing press'
#  b'common man had access to the same']
# [300 204]
#  Gutenberg invented the printing press
# common   to the same
# [b'darling gentlemen might I interrupt your'
#  b'information that used to be available']
# [300 242]
# darling gentlemen might I interrupt your
# information that used to  available
# 56.822524070739746
# Model saved in file: /home/saurabh/Documents/tf_orange/tf_orange/models/feeny/model.ckpt
